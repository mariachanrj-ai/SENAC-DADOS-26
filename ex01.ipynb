# %%
import pandas as pd
import numpy as np  # permite trabalhar estatistica

# %%
dados = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'
df = pd.read_csv(dados, sep=';', encoding='latin1')

(df.head())
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# ...

# %%
df.tail()    # retorna apenas o último comando de display
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 37309   159    1  2026  2026m01    35     4  Cachoeiras de Macacu  3300803
# 37310   165    1  2026  2026m01    33     5           Mangaratiba  3302601
# 37311   166    1  2026  2026m01    33     5        Angra dos Reis  3300100
# 37312   167    1  2026  2026m01    43     5                Paraty  3303807
# 37313   168    1  2026  2026m01    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 37309  Interior           1  ...   2.0   0.0      37                      1
# 37310  Interior           0  ...   3.0   0.0      32                      0
# 37311  Interior           2  ...  10.0   0.0      98                      9
# 37312  Interior           1  ...   3.0   0.0      25                      2
# 37313  Interior           1  ...   0.0   0.0       3                      0
#
# ...

# %%
df_furto_celular_cisp = df.groupby('cisp')['furto_celular'].sum().reset_index()  #qual o furto de celular por delegacia?
df_furto_celular_cisp
# Out:
#      cisp  furto_celular
# 0       1          15487
# 1       4          13700
# 2       5          23969
# 3       6           6410
# 4       7           1485
# ..    ...            ...
# 133   159            455
# 134   165           1233
# 135   166           2580
# 136   167            497
# 137   168            121
#
# [138 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37314 entries, 0 to 37313
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        37314 non-null  int64
#  1   mes                         37314 non-null  int64
#  2   ano                         37314 non-null  int64
#  3   mes_ano                     37314 non-null  str
#  4   aisp                        37314 non-null  int64
#  5   risp                        37314 non-null  int64
#  6   munic                       37314 non-null  str
#  7   mcirc                       37314 non-null  int64
#  8   regiao                      37314 non-null  str
#  9   hom_doloso                  37314 non-null  int64
#  10  lesao_corp_morte            37314 non-null  int64
#  11  latrocinio                  37314 non-null  int64
#  12  cvli                        37314 non-null  int64
# ...

# %%
df.describe()   #pega todas as colunas e dá as estatísticas - conta, média, min, 25%, 50%, 75%
# Out:
#                cisp           mes           ano          aisp          risp  \
# count  37314.000000  37314.000000  37314.000000  37314.000000  37314.000000
# mean      81.724259      6.482232   2014.188723     20.148470      3.869942
# std       48.320410      3.461767      6.625316     11.348509      2.011450
# min        1.000000      1.000000   2003.000000      1.000000      1.000000
# 25%       38.000000      3.000000   2008.000000     10.000000      2.000000
# 50%       78.000000      6.000000   2014.000000     20.000000      4.000000
# 75%      125.000000      9.000000   2020.000000     30.000000      6.000000
# max      168.000000     12.000000   2026.000000     43.000000      7.000000
#
#               mcirc    hom_doloso  lesao_corp_morte    latrocinio  \
# count  3.731400e+04  37314.000000      37314.000000  37314.000000
# mean   3.791939e+06      2.925256          0.028140      0.095380
# std    1.741132e+06      4.327953          0.179516      0.366265
# ...

# %%
df.shape #quantidade de linhas e colunas
# Out:
# (37314, 65)

# %%
df.columns #retorna o nome de todas colunas
# Out:
# Index(['cisp', 'mes', 'ano', 'mes_ano', 'aisp', 'risp', 'munic', 'mcirc',
#        'regiao', 'hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli',
#        'hom_por_interv_policial', 'feminicidio', 'letalidade_violenta',
#        'tentat_hom', 'tentativa_feminicidio', 'lesao_corp_dolosa', 'estupro',
#        'hom_culposo', 'lesao_corp_culposa', 'roubo_transeunte',
#        'roubo_celular', 'roubo_em_coletivo', 'roubo_rua', 'roubo_veiculo',
#        'roubo_carga', 'roubo_comercio', 'roubo_residencia', 'roubo_banco',
#        'roubo_cx_eletronico', 'roubo_conducao_saque', 'roubo_apos_saque',
#        'roubo_bicicleta', 'outros_roubos', 'total_roubos', 'furto_veiculos',
#        'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
# ...

# %%
df.iloc[0:5]  #apresenta da 1a até a 5a linha
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# ...

# %%
df_rj =df.loc[df['munic'] == 'Rio de Janeiro']  #retorna apenas dados do Rio de Janeiro
display(df_rj)
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1         4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2         5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3         6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4         7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 37213    40    1  2026  2026m01     9     2  Rio de Janeiro  3304557  Capital
# 37214    41    1  2026  2026m01    18     2  Rio de Janeiro  3304557  Capital
# 37215    42    1  2026  2026m01    31     2  Rio de Janeiro  3304557  Capital
# 37216    43    1  2026  2026m01    27     2  Rio de Janeiro  3304557  Capital
# 37217    44    1  2026  2026m01     3     1  Rio de Janeiro  3304557  Capital
#
# ...

# %%
df_capital_2020 = df.loc[(df['ano'] == 2020) & (df['regiao'] == 'Capital')]
df_capital_2020
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 27313     1    1  2020  2020m01     5     1  Rio de Janeiro  3304557  Capital
# 27314     4    1  2020  2020m01     5     1  Rio de Janeiro  3304557  Capital
# 27315     5    1  2020  2020m01     5     1  Rio de Janeiro  3304557  Capital
# 27316     6    1  2020  2020m01     4     1  Rio de Janeiro  3304557  Capital
# 27317     7    1  2020  2020m01     5     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 28856    40   12  2020  2020m12     9     2  Rio de Janeiro  3304557  Capital
# 28857    41   12  2020  2020m12    18     2  Rio de Janeiro  3304557  Capital
# 28858    42   12  2020  2020m12    31     2  Rio de Janeiro  3304557  Capital
# 28859    43   12  2020  2020m12    27     2  Rio de Janeiro  3304557  Capital
# 28860    44   12  2020  2020m12     3     1  Rio de Janeiro  3304557  Capital
#
# ...

# %%
df_2024 = df.loc[df['ano'] == 2024] #retorna apenas dados de 2024
print(df_2024)
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 33889     1    1  2024  2024m01     5     1        Rio de Janeiro  3304557
# 33890     4    1  2024  2024m01     5     1        Rio de Janeiro  3304557
# 33891     5    1  2024  2024m01     5     1        Rio de Janeiro  3304557
# 33892     6    1  2024  2024m01     4     1        Rio de Janeiro  3304557
# 33893     7    1  2024  2024m01     5     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 35528   159   12  2024  2024m12    35     4  Cachoeiras de Macacu  3300803
# 35529   165   12  2024  2024m12    33     5           Mangaratiba  3302601
# 35530   166   12  2024  2024m12    33     5        Angra dos Reis  3300100
# 35531   167   12  2024  2024m12    43     5                Paraty  3303807
# 35532   168   12  2024  2024m12    28     5             Rio Claro  3304409
#
# ...

# %%
dados = np.array([12, 15, 17, 20, 22, 25, 28, 30, 35, 40])  #array é estrutura específica da biblioteca numpy
q1 = np.percentile(dados, 25)
q2 = np.percentile(dados, 50)
q3 = np.percentile(dados, 75)
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
# Out:
# Primeiro quartil (Q1): 17.75
# Segundo quartil (Q2): 23.5
# Terceiro quartil (Q3): 29.5

# %%
array_furto_celular = np.array(df_furto_celular_cisp['furto_celular'])
q1_furto_celular = np.percentile(array_furto_celular, 25)
q2_furto_celular = np.percentile(array_furto_celular, 50)
q3_furto_celular = np.percentile(array_furto_celular, 75)
media = np.mean(array_furto_celular)
mediana = np.median(array_furto_celular)
distancia = (media - mediana) / mediana
print(f'Primeiro quartil (Q1): {q1_furto_celular}')
print(f'Segundo quartil (Q2): {q2_furto_celular}')
print(f'Terceiro quartil (Q3): {q3_furto_celular}')
print(f'O valor de média é {media}')
print(f'O valor da mediana é {mediana}')
print(f'A distancia entre média e mediana é de {distancia}')
# Out:
# Primeiro quartil (Q1): 451.25
# Segundo quartil (Q2): 1675.5
# Terceiro quartil (Q3): 4580.0
# O valor de média é 3422.978260869565
# O valor da mediana é 1675.5
# A distancia entre média e mediana é de 1.042959272378135

# %%
df_menor_q1_furto_celular = df_furto_celular_cisp.loc[df_furto_celular_cisp['furto_celular'] < q1_furto_celular]
df_menor_q1_furto_celular = df_menor_q1_furto_celular.sort_values(by='furto_celular', ascending=False)
df_menor_q1_furto_celular
# Out:
#      cisp  furto_celular
# 99    121            450
# 90    107            446
# 84     99            435
# 85    100            401
# 7      11            392
# 60     67            372
# 79     94            367
# 115   139            364
# 86    101            356
# 111   135            355
# 113   137            303
# 98    120            299
# 127   153            254
# 108   130            242
# 82     97            233
# 95    112            211
# 61     70            202
# 100   122            202
# 124   148            195
# 116   140            165
# 123   147            165
# 132   158            154
# 92    109            143
# 118   142            128
# 137   168            121
# 126   152            109
# 130   156            109
# 83     98             90
# 94    111             82
# 41     45             73
# 87    104             72
# 77     92             65
# 131   157             55
# 114   138             53
# 129   155             47

# %%
df_regiao_metropolitana = df.loc[(df['municip'] == 'Rio de Janeiro') & (df['municip'] == 'Capital')]
df_capital_2020df_furto_celular_regiaoMetropolitana = df.groupby(municip)

# %%
df_apreensao_menor_cisp = df.groupby('cisp')['aaapai'].sum().reset_index()  #qual apreensao de menor por delegacia?
display(df_apreensao_menor_cisp)
array_apreensao_menor = np.array(df_apreensao_menor_cisp['aaapai'])
q1_apreensao_menor = np.percentile(array_apreensao_menor, 25)
q2_apreensao_menor = np.percentile(array_apreensao_menor, 50)
q3_apreensao_menor = np.percentile(array_apreensao_menor, 75)
print(f'Primeiro quartil (Q1): {q1_apreensao_menor}')
print(f'Segundo quartil (Q2): {q2_apreensao_menor}')
print(f'Terceiro quartil (Q3): {q3_apreensao_menor}')
df_maior_apreensao_menor = df_apreensao_menor_cisp.loc[df_apreensao_menor_cisp['aaapai'] > q3_apreensao_menor]
df_maior_apreensao_menor

# %%
df_aaapai_cap_2020 = df_capital_2020.groupby('cisp')['aaapai'].sum().reset_index()
df_aaapai_cap_2020 = df_aaapai_cap_2020.sort_values(by='aaapai', ascending=False)
df_aaapai_cap_2020

# %%
gestao_atual = [2023,2024,2025,2026]
df_interior_atual = df.loc[(df['regiao'] == 'Interior') & (df['ano']).isin(gestao_atual)]  #isin busca dados dentro da lista
df_interior_atual

# %%
#furto celular em 2024 na regiao metropolitana estado Rio de Janeiro
regiao_metropolitana = [
    'Rio de Janeiro','Niterói','São Gonçalo','Duque de Caxias', 
    'Nova Iguaçu', 'Belford Roxo','São João de Meriti', 
    'Nilópolis','Mesquita', 'Itaguaí', 'Magé', 'Guapimirim',
    'Paracambi','Queimaos','Seropédica','Tanguá','Rio Bonito','Cachoeiras de Macacu']
print(regiao_metropolitana)

# %%
df_rm_24 = df.loc[(df['ano'] ==2024) & (df['munic'].isin(regiao_metropolitana))]  #rm regiao metropolitana

# %%
df_furto_cel_rm_24 = df_rm_24.groupby('cisp')['furto_celular'].sum().reset_index()

array_furto_celular = np.array(df_furto_cel_rm_24['furto_celular'])
media = np.mean(array_furto_celular)
mediana = np.median(array_furto_celular)
distancia = (media-mediana) / mediana
print(f'O valor de média é {media}')
print(f'O valor de mediana é {mediana}')
print(f'A distância entre média e mediana é de {round(distancia,2) * 100}%')
# Out:
# O valor de média é 482.8857142857143
# O valor de mediana é 242.5
# A distância entre média e mediana é de 99.0%

# %%
munic = df.groupby('munic').size().reset_index(name='quantidade') #contar os municipios
munic
